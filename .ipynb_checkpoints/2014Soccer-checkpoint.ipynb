# %%
import json
import requests
import random
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
soccer_data_df = pd.read_csv("data/team_data.csv")
soccer_data_df.head()
# Out:
#                      Team Group Advanced  Rankings  Standing  WikiStanding  \
# 0                 Algeria     H        Y        21         9            14
# 1               Argentina     F        Y         5         2             2
# 2               Australia     B        N        32        17            30
# 3                 Belgium     H        Y        11         5             6
# 4  Bosnia and Herzegovina     F        N        20        17            20
#
#    Ranking Differential  Points in Group Round  Games Played  Goals  \
# 0                     7                      4             4      7
# 1                     3                      9             7      8
# 2                     2                      3             3      3
# 3                     5                      9             5      6
# 4                     0                      3             3      4
#
#            ...            Miles per Game  Value of players (in million euros)  \
# ...

# %%
plt.scatter(soccer_data_df["WikiStanding"], soccer_data_df["Short Passes per Game"], c="blue", alpha=0.7, linewidth=1, marker="o", edgecolors="black")
plt.grid(True)
plt.xlim(35, 0)
plt.xlabel("Ranking")
plt.ylabel("Miles per Game")
plt.title("Ranking vs. Miles per Game")
plt.show()

# %%
plt.scatter(soccer_data_df["WikiStanding"], soccer_data_df["Miles per Game"], c="blue", alpha=0.7, linewidth=1, marker="o", edgecolors="black")
plt.grid(True)
plt.xlim(35, 0)
plt.xlabel("Ranking")
plt.ylabel("Miles per Game")
plt.title("Ranking vs. Miles per Game")
plt.show()

# %%
plt.figure(figsize=(20,10))

shots_per_game = soccer_data_df["Shots per Game"]
x_axis = np.arange(len(shots_per_game))
x_axis

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, soccer_data_df["Team"], rotation=70)

# Sets the x limits of the current chart
#plt.xlim(-0.75, len(x_axis)-0.25)

# Sets the y limits of the current chart
#plt.ylim(0, max(users)+5000)

# Give our chart some labels and a tile
plt.title("Team Shots per Game")
plt.xlabel("Team")
plt.ylabel("Shots per Game")

plt.bar(x_axis, shots_per_game, color='r', alpha=0.5, align="center")

# Print our chart to the screen
plt.show()

# %%
#team_shots = soccer_data_df.loc[(soccer_data_df["Advanced"] == "Y")]
team_shots = soccer_data_df[["Team","Shots per Game", "Advanced"]]

team_shots = team_shots.set_index("Team").sort_values("Shots per Game", ascending=False)
   
    
team_shots.plot(kind="bar", figsize=(20,10), rot=70, width=.7)

plt.title("Team Shots per Game")

plt.show()

# %%
appearances = pd.read_csv("desktop/champteam/data/pie_graph_appearances.csv")
appearances.head()
# Out:
#   Unnamed: 0  AFC  CAF  CONCACAF  CONMEBOL  OFC  UEFA  Total
# 0      Teams   37   44        42        85    4   245    457
# 1     Top 16    5    9        13        31    1    81    140
# 2      Top 8    2    3         5        32    0    94    136
# 3      Top 4    1    0         1        22    0    56     80
# 4      Top 2    0    0         0        14    0    26     40

# %%
sizes = appearances.iloc[0,1:7]
sizes
# Out:
# AFC          37
# CAF          44
# CONCACAF     42
# CONMEBOL     85
# OFC           4
# UEFA        245
# Name: 0, dtype: object

# %%
# Labels for the sections of our pie chart
labels = ["AFC","CAF","CONCACAF","CONMEBOL","OFC","UEFA"]

# The values of each section of the pie chart
sizes = [1, 0, 1, 22, 0, 56]

# The colors of each section of the pie chart
colors = ["yellowgreen", "red", "lightcoral", "lightskyblue", "yellow", "green", "blue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0, 0, 0, 0.1)

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
# enables auto percent you to display percent values using python formatting 
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")
plt.title("Top 4")

# Prints our pie chart to the screen
plt.show()

# %%
# Labels for the sections of our pie chart
labels = ["AFC","CAF","CONCACAF","CONMEBOL","OFC","UEFA"]

# The values of each section of the pie chart
sizes = [2, 3, 5, 32, 0, 94]

# The colors of each section of the pie chart
colors = ["yellowgreen", "red", "lightcoral", "lightskyblue", "yellow", "green", "blue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0, 0, 0, 0.1)

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
# enables auto percent you to display percent values using python formatting 
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")
plt.title("Top 16")

# Prints our pie chart to the screen
plt.show()

# %%
# Labels for the sections of our pie chart
labels = ["AFC","CAF","CONCACAF","CONMEBOL","OFC","UEFA"]

# The values of each section of the pie chart
sizes = [5, 9, 13, 31, 1, 81]

# The colors of each section of the pie chart
colors = ["yellowgreen", "red", "lightcoral", "lightskyblue", "yellow", "green", "blue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0, 0, 0, 0.1)

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
# enables auto percent you to display percent values using python formatting 
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")
plt.title("Top 8")

# Prints our pie chart to the screen
plt.show()

# %%
sns.lmplot(soccer_data_df["WikiStanding"], soccer_data_df["Miles per Game"], data=soccer_data_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-266-c7d61f52664a> in <module>()
# ----> 1 sns.lmplot(soccer_data_df["WikiStanding"], soccer_data_df["Miles per Game"], data=soccer_data_df)
#
# /anaconda3/lib/python3.6/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     550     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     551     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 552     data = data[cols]
#     553
#     554     # Initialize the grid
#
# ...

# %%
group_a = soccer_data_df.loc[(soccer_data_df["Group"] == "A")]
group_a
# Out:
#         Team Group Advanced  Rankings  Standing  WikiStanding  \
# 5     Brazil     A        Y         3         4             4
# 6   Cameroon     A        N        30        17            32
# 10   Croatia     A        N        17        17            19
# 22    Mexico     A        Y        19         9            10
#
#     Ranking Differential  Points in Group Round  Games Played  Goals  \
# 5                     -1                      7             7     11
# 6                     -2                      0             3      1
# 10                    -2                      3             3      6
# 22                     9                      7             4      5
#
#             ...            Miles per Game  \
# 5           ...                     66.36
# 6           ...                     60.45
# 10          ...                     65.12
# 22          ...                     66.06
#
#     Value of players (in million euros)  Possession Percentage  \
# ...
